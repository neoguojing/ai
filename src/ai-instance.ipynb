# %%
import sys
sys.path.insert(0, '')
from instance_seg import instance_segmentation
from tools import draw_instance

# %%
boxes,labels,masks = instance_segmentation("/workspace/tests/seg2.jpeg","maskrcnn")

# %%
boxes,labels,masks = instance_segmentation("/workspace/tests/seg2.jpeg","yolact")

# %%
draw_instance("/workspace/tests/seg2.jpeg",boxes,labels,masks)
