# %%
import sys
sys.path.insert(0, '')
from semantic_seg import semantic_segmentation
from tools import draw_masks

# %%
result,image_shape = semantic_segmentation("/workspace/tests/seg2.jpeg","pspnet")

# %%
result,image_shape = semantic_segmentation("/workspace/tests/seg2.jpeg","deeplabv3")

# %%
result,image_shape = semantic_segmentation("/workspace/tests/seg2.jpeg","bisenetv1")

# %%
draw_masks("/workspace/tests/seg2.jpeg",result,image_shape[2])
